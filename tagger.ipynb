# %%
import argparse
import os
from pprint import pprint

from anago.utils import load_data_and_labels,NERSequence
from anago.models import BiLSTMCRF,load_model,save_model
from anago.preprocessing import IndexTransformer#, ELMoTransformer
from anago.trainer import Trainer
from anago.tagger import Tagger
# Out:
# Using TensorFlow backend.

# %%
from lang_util.spell import SpellCorrector


spell = SpellCorrector()
def correct_spell(sentence):
    sentence = " ".join(sentence)
    sentence = spell.validate(sentence)
    sentence = sentence.split(' ')
    return sentence

# %%
dir_path = os.getcwd()
model_dir = os.path.realpath(os.path.join(dir_path,"./models/multitags"))
#train_data = os.path.realpath(os.path.join(dir_path,"../data/train.iob"))
#valid_data = os.path.realpath(os.path.join(dir_path,"../data/test.iob"))
weights_file = os.path.realpath(os.path.join(model_dir,"weights.h5"))
params_file = os.path.realpath(os.path.join(model_dir,"params.json"))
preprocessor_file = os.path.realpath(os.path.join(model_dir,"preprocessor.bin"))

print(weights_file)
print(params_file)
# Out:
# /home/novan/work/ml/jupyter/models/multitags/weights.h5
# /home/novan/work/ml/jupyter/models/multitags/params.json

# %%
print('Loading objects...')
model = load_model(weights_file, params_file)
it = IndexTransformer.load(preprocessor_file)
tagger = Tagger(model, preprocessor=it)
# Out:
# Loading objects...
# WARNING:tensorflow:From /home/novan/work/ml/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 12/24/2018 13:34:52 - WARNING - tensorflow -   From /home/novan/work/ml/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/novan/work/ml/jupyter/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 12/24/2018 13:34:52 - WARNING - tensorflow -   From /home/novan/work/ml/jupyter/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
text = []
text.append("kalau saat masa subur saya dan sumi melakukan snggama terputus apakah mungkin masih bisa haml")
#text = "raynaldy kelebihan berat badan yang bisa menyebabkan diabetes"
# text.append("masa subur sore dok. saya mau tanya, tanggal 05 juli 2018 nanti saya menikah. hari ini 21 juni 2018 saya haid hari pertama untuk periode juni. kira-kira masa subur saya tanggal berapa? karena saya dan calon sami berencana langsung memiliki momongan..")
# text.append("ambyen dok saya berusia 20thn \
#  namun ambeyen saya sudah sangat besar dan tidak dapat masuk kedalam dubur lagi \
#  saya pernah periksakan namun hanya diberikan obat \
#  tapi tidak ada reaksi \
#  bagaimana ini dok \
#  cara menyembuhkan wasir \
#  tanpa ambil resiko operasi .\
#  dan makanana apa saja yang harus dihindari")

# text.append("bekas jerawat dok ngilangin bekas jerawat pake apa yah? bekas jerawat saya di seblah pipi kanan gak ilang2.\
# trus mau tanya jg kalau pelembab di pake setiap hari buat kulit yg ada bekas jerawat aman gk? wlpn itu gak keluar rumah")

# text.append("thyroid Dok, tiroid bisa menyebabkan jantung berdebar? Apa yg harus saya lakukan jika kambuh?")
# text.append("klnjar tiroid dok kenapa yah smenjak saya mmiliki kelenjar tiroid saya slalu mrasa gelisah suasana hati kadang berubah apakah iitu ada hubunganya dengan benjolan saya")
text.append("dok anak saya umur 2th 6 bulan kemasukan air tlinganya lalu saya baw ke klinik bpjs dan dberi obt puyr dan amoxcilin dan sekarang baik obat maupun amoxcilin sudah habis diminum tp tlinga msh keluar cairan agak kental jadi saya harus bagaimana dok")
text.append("Kulit Bu kalau obat dermatix apakah bisa menghilangkan luka yg belang istilahnya bisa mengembalikan kulit yg brlang menjadi kulit lagi gak bu?")
text.append("wajah dok penyebab kulit kusam terjadi karena apa dok dan cara mengatasinya agar kuliy wajah terlihat cerah")
text.append("penyakit anus keluar cairan bau 4 hr sudah keponakan saya terbaring di tempat tdr mula nya sakit kepala demam terus panas dingin 2 hr ini ko keluar cairan dari anus yg mengeluarkan bau tidak sedap")
text.append("skrang ni saya lagi hamil 4bln 2week,  prtnyaannya knpa yah kulit saya trlihat menghitam.")
text.append("ever whit buat bumil dok aman g jika saya pke pemutih badan ever white")

text.append("paman saya pnisnya kantung telurnya bengkak")

text.append("ibu mertua saya mengeluh diabetes gula darah tinggi, saya harus bagaimana")
print('Tagging a sentence...')

for t in text:
    t = spell.validate(t)
    print (t)
    res = tagger.analyze(t)
    pprint(res)
    #proba = tagger.predict_proba(t)
    #pprint(proba)
    #print(len(proba))
    #print(len(res['words']))
# Out:
# Tagging a sentence...
# kalau saat masa subur saya dan suami melakukan senggama terputus apakah mungkin masih bisa hamil
# {'entities': [{'beginOffset': 6,
#                'endOffset': 7,
#                'score': 1.0,
#                'text': 'suami',
#                'type': 'MAN'},
#               {'beginOffset': 6,
#                'endOffset': 7,
#                'score': 1.0,
#                'text': 'suami',
#                'type': 'ADULT'},
#               {'beginOffset': 8,
#                'endOffset': 10,
#                'score': 1.0,
#                'text': 'senggama terputus',
#                'type': 'ACTIVITY'}],
#  'words': ['kalau',
#            'saat',
#            'masa',
#            'subur',
#            'saya',
#            'dan',
#            'suami',
#            'melakukan',
#            'senggama',
#            'terputus',
#            'apakah',
#            'mungkin',
#            'masih',
#            'bisa',
#            'hamil']}
# dok anak saya umur 2th 6 bulan kemasukan air telinganya lalu saya bawa ke klinik bpjs dan diberi obat puyr dan amoxcilin dan sekarang baik obat maupun amoxcilin sudah habis diminum tapi telinga msh keluar cairan agak kental jadi saya harus bagaimana dok
# {'entities': [{'beginOffset': 1,
#                'endOffset': 3,
#                'score': 1.0,
#                'text': 'anak saya',
#                'type': 'SOMEONE'},
#               {'beginOffset': 5,
#                'endOffset': 7,
#                'score': 1.0,
#                'text': '6 bulan',
#                'type': 'BABY'},
#               {'beginOffset': 8,
#                'endOffset': 10,
#                'score': 1.0,
#                'text': 'air telinganya',
#                'type': 'BBODY'},
#               {'beginOffset': 18,
#                'endOffset': 20,
#                'score': 1.0,
#                'text': 'obat puyr',
#                'type': 'TREATMENT'},
#               {'beginOffset': 21,
#                'endOffset': 22,
#                'score': 1.0,
#                'text': 'amoxcilin',
#                'type': 'TREATMENT'},
#               {'beginOffset': 27,
#                'endOffset': 28,
#                'score': 1.0,
#                'text': 'amoxcilin',
#                'type': 'TREATMENT'},
#               {'beginOffset': 32,
#                'endOffset': 33,
#                'score': 1.0,
#                'text': 'telinga',
#                'type': 'BBODY'},
#               {'beginOffset': 35,
#                'endOffset': 38,
#                'score': 1.0,
#                'text': 'cairan agak kental',
#                'type': 'SYMPTOM'}],
#  'words': ['dok',
#            'anak',
#            'saya',
#            'umur',
#            '2th',
#            '6',
#            'bulan',
#            'kemasukan',
#            'air',
#            'telinganya',
#            'lalu',
#            'saya',
#            'bawa',
#            'ke',
#            'klinik',
#            'bpjs',
#            'dan',
#            'diberi',
#            'obat',
#            'puyr',
#            'dan',
#            'amoxcilin',
#            'dan',
#            'sekarang',
#            'baik',
#            'obat',
#            'maupun',
#            'amoxcilin',
#            'sudah',
#            'habis',
#            'diminum',
#            'tapi',
#            'telinga',
#            'msh',
#            'keluar',
#            'cairan',
#            'agak',
#            'kental',
#            'jadi',
#            'saya',
#            'harus',
#            'bagaimana',
#            'dok']}
# kulit bu kalau obat dermatix apakah bisa menghilangkan luka yg belang istilahnya bisa mengembalikan kulit yg berulang menjadi kulit lagi agak bu?
# {'entities': [{'beginOffset': 0,
#                'endOffset': 1,
#                'score': 1.0,
#                'text': 'kulit',
#                'type': 'BBODY'},
#               {'beginOffset': 4,
#                'endOffset': 5,
#                'score': 1.0,
#                'text': 'dermatix',
#                'type': 'TREATMENT'},
#               {'beginOffset': 8,
#                'endOffset': 9,
#                'score': 1.0,
#                'text': 'luka',
#                'type': 'DISEASE'},
#               {'beginOffset': 14,
#                'endOffset': 15,
#                'score': 1.0,
#                'text': 'kulit',
#                'type': 'BBODY'},
#               {'beginOffset': 18,
#                'endOffset': 19,
#                'score': 1.0,
#                'text': 'kulit',
#                'type': 'BBODY'}],
#  'words': ['kulit',
#            'bu',
#            'kalau',
#            'obat',
#            'dermatix',
#            'apakah',
#            'bisa',
#            'menghilangkan',
#            'luka',
#            'yg',
#            'belang',
#            'istilahnya',
#            'bisa',
#            'mengembalikan',
#            'kulit',
#            'yg',
#            'berulang',
#            'menjadi',
#            'kulit',
#            'lagi',
#            'agak',
#            'bu?']}
# wajah dok penyebab kulit kusam terjadi karena apa dok dan cara mengatasinya agar kuliy wajah terlihat cerah
# {'entities': [{'beginOffset': 0,
#                'endOffset': 1,
#                'score': 1.0,
#                'text': 'wajah',
#                'type': 'BBODY'},
#               {'beginOffset': 3,
#                'endOffset': 4,
#                'score': 1.0,
#                'text': 'kulit',
#                'type': 'BBODY'},
#               {'beginOffset': 4,
#                'endOffset': 5,
#                'score': 1.0,
#                'text': 'kusam',
#                'type': 'SYMPTOM'},
#               {'beginOffset': 14,
#                'endOffset': 15,
#                'score': 1.0,
#                'text': 'wajah',
#                'type': 'BBODY'}],
#  'words': ['wajah',
#            'dok',
#            'penyebab',
#            'kulit',
#            'kusam',
#            'terjadi',
#            'karena',
#            'apa',
#            'dok',
#            'dan',
#            'cara',
#            'mengatasinya',
#            'agar',
#            'kuliy',
#            'wajah',
#            'terlihat',
#            'cerah']}
# penyakit anus keluar cairan bau 4 hari sudah keponakan saya terbaring di tempat tidur mula nya sakit kepala demam terus panas dingin 2 hari ini konon keluar cairan dari anus yg mengeluarkan bau tidak sedap
# {'entities': [{'beginOffset': 1,
#                'endOffset': 2,
#                'score': 1.0,
#                'text': 'anus',
#                'type': 'BBODY'},
#               {'beginOffset': 3,
#                'endOffset': 5,
#                'score': 1.0,
#                'text': 'cairan bau',
#                'type': 'SYMPTOM'},
#               {'beginOffset': 8,
#                'endOffset': 10,
#                'score': 1.0,
#                'text': 'keponakan saya',
#                'type': 'SOMEONE'},
#               {'beginOffset': 16,
#                'endOffset': 17,
#                'score': 1.0,
#                'text': 'sakit',
#                'type': 'SYMPTOM'},
#               {'beginOffset': 17,
#                'endOffset': 18,
#                'score': 1.0,
#                'text': 'kepala',
#                'type': 'BBODY'},
#               {'beginOffset': 18,
#                'endOffset': 19,
#                'score': 1.0,
#                'text': 'demam',
#                'type': 'SYMPTOM'},
#               {'beginOffset': 20,
#                'endOffset': 22,
#                'score': 1.0,
#                'text': 'panas dingin',
#                'type': 'SYMPTOM'},
#               {'beginOffset': 26,
#                'endOffset': 28,
#                'score': 1.0,
#                'text': 'keluar cairan',
#                'type': 'SYMPTOM'},
#               {'beginOffset': 29,
#                'endOffset': 30,
#                'score': 1.0,
#                'text': 'anus',
#                'type': 'BBODY'},
#               {'beginOffset': 32,
#                'endOffset': 33,
#                'score': 1.0,
#                'text': 'bau',
#                'type': 'SYMPTOM'}],
#  'words': ['penyakit',
#            'anus',
#            'keluar',
#            'cairan',
#            'bau',
#            '4',
#            'hari',
#            'sudah',
#            'keponakan',
#            'saya',
#            'terbaring',
#            'di',
#            'tempat',
#            'tidur',
#            'mula',
#            'nya',
#            'sakit',
#            'kepala',
#            'demam',
#            'terus',
#            'panas',
#            'dingin',
#            '2',
#            'hari',
#            'ini',
#            'konon',
#            'keluar',
#            'cairan',
#            'dari',
#            'anus',
#            'yg',
#            'mengeluarkan',
#            'bau',
#            'tidak',
#            'sedap']}
# sekarang ini saya lagi hamil 4bln 2week, pertanyaannya kenapa yah kulit saya terlihat menghitam.
# {'entities': [{'beginOffset': 4,
#                'endOffset': 5,
#                'score': 1.0,
#                'text': 'hamil',
#                'type': 'PREGNANT'},
#               {'beginOffset': 5,
#                'endOffset': 6,
#                'score': 1.0,
#                'text': '4bln',
#                'type': 'DURATION'},
#               {'beginOffset': 10,
#                'endOffset': 11,
#                'score': 1.0,
#                'text': 'kulit',
#                'type': 'BBODY'}],
#  'words': ['sekarang',
#            'ini',
#            'saya',
#            'lagi',
#            'hamil',
#            '4bln',
#            '2week,',
#            'pertanyaannya',
#            'kenapa',
#            'yah',
#            'kulit',
#            'saya',
#            'terlihat',
#            'menghitam.']}
# ever white buat bumil dok aman g jika saya pike pemutih badan ever white
# {'entities': [{'beginOffset': 0,
#                'endOffset': 2,
#                'score': 1.0,
#                'text': 'ever white',
#                'type': 'TREATMENT'},
#               {'beginOffset': 3,
#                'endOffset': 4,
#                'score': 1.0,
#                'text': 'bumil',
#                'type': 'PREGNANT'},
#               {'beginOffset': 10,
#                'endOffset': 12,
#                'score': 1.0,
#                'text': 'pemutih badan',
#                'type': 'TREATMENT'},
#               {'beginOffset': 12,
#                'endOffset': 14,
#                'score': 1.0,
#                'text': 'ever white',
#                'type': 'TREATMENT'}],
#  'words': ['ever',
#            'white',
#            'buat',
#            'bumil',
#            'dok',
#            'aman',
#            'g',
#            'jika',
#            'saya',
#            'pike',
#            'pemutih',
#            'badan',
#            'ever',
#            'white']}
# paman saya penisnya kantung telurnya bengkak
# {'entities': [{'beginOffset': 0,
#                'endOffset': 2,
#                'score': 1.0,
#                'text': 'paman saya',
#                'type': 'SOMEONE'},
#               {'beginOffset': 0,
#                'endOffset': 1,
#                'score': 1.0,
#                'text': 'paman',
#                'type': 'MAN'},
#               {'beginOffset': 0,
#                'endOffset': 1,
#                'score': 1.0,
#                'text': 'paman',
#                'type': 'ADULT'},
#               {'beginOffset': 2,
#                'endOffset': 3,
#                'score': 1.0,
#                'text': 'penisnya',
#                'type': 'BBODY'},
#               {'beginOffset': 3,
#                'endOffset': 5,
#                'score': 1.0,
#                'text': 'kantung telurnya',
#                'type': 'DISEASE'},
#               {'beginOffset': 5,
#                'endOffset': 6,
#                'score': 1.0,
#                'text': 'bengkak',
#                'type': 'SYMPTOM'}],
#  'words': ['paman', 'saya', 'penisnya', 'kantung', 'telurnya', 'bengkak']}
# ibu mertua saya mengeluh diabetes gula darah tinggi, saya harus bagaimana
# {'entities': [{'beginOffset': 0,
#                'endOffset': 1,
#                'score': 1.0,
#                'text': 'ibu',
#                'type': 'WOMAN'},
#               {'beginOffset': 0,
#                'endOffset': 1,
#                'score': 1.0,
#                'text': 'ibu',
#                'type': 'ADULT'},
#               {'beginOffset': 1,
#                'endOffset': 3,
#                'score': 1.0,
#                'text': 'mertua saya',
#                'type': 'SOMEONE'},
#               {'beginOffset': 1,
#                'endOffset': 2,
#                'score': 1.0,
#                'text': 'mertua',
#                'type': 'ADULT'},
#               {'beginOffset': 4,
#                'endOffset': 7,
#                'score': 1.0,
#                'text': 'diabetes gula darah',
#                'type': 'DISEASE'}],
#  'words': ['ibu',
#            'mertua',
#            'saya',
#            'mengeluh',
#            'diabetes',
#            'gula',
#            'darah',
#            'tinggi,',
#            'saya',
#            'harus',
#            'bagaimana']}

# %%
b = "B-WOMAN"
c = {'b':b}
print (b.split(" "))
x,y = b.split('-')
print(x)
print(y)

print ( None or 1 )
# Out:
# ['B-WOMAN']
# B
# WOMAN
# 1
